# %%
import os
import re
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Conv2D, UpSampling2D, BatchNormalization, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.models import load_model

def rgb_to_three_channel_grayscale(image):
    grayscale_image = tf.image.rgb_to_grayscale(image)
    return tf.repeat(grayscale_image, repeats=3, axis=-1)

def preprocess_image(rgb_path, target_size=(200, 200)):
    rgb_image = tf.io.read_file(rgb_path)
    rgb_image = tf.image.decode_png(rgb_image, channels=3)
    rgb_image = tf.image.resize(rgb_image, target_size)
    return rgb_image / 255.0

def parse_image_filename(filename, zones):
    match = re.search(r'image\.(\d+)\.rgb\.png', filename)
    if match:
        azimuth = int(match.group(1)) % 360
        return azimuth // (360 // zones)
    return 0

def split_dataset(data, split_ratios=(0.8, 0.1, 0.1)):
    indices = np.random.permutation(len(data))
    split1 = int(split_ratios[0] * len(data))
    split2 = split1 + int(split_ratios[1] * len(data))
    return [data[i] for i in indices[:split1]], [data[i] for i in indices[split1:split2]], [data[i] for i in indices[split2:]]

def create_dataset(image_paths, labels, preprocess_func):
    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_func, num_parallel_calls=tf.data.AUTOTUNE)
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((image_ds, label_ds))

def load_images_from_directory(base_dir, preprocess_func, split_ratios=(0.7, 0.2, 0.1)):
    all_image_paths, all_labels = [], []
    for folder_name in sorted(os.listdir(base_dir)):
        folder_path = os.path.join(base_dir, folder_name)
        if os.path.isdir(folder_path):
            for filename in sorted(os.listdir(folder_path)):
                if filename.endswith(".rgb.png"):
                    elevation = int(folder_name)
                    file_path = os.path.join(folder_path, filename)
                    all_image_paths.append(file_path)
                    all_labels.append(elevation)

    # Shuffle the dataset
    indices = np.random.permutation(len(all_image_paths))
    all_image_paths = np.array(all_image_paths)[indices]
    all_labels = np.array(all_labels)[indices]

    # Split the dataset
    train_size = int(len(all_image_paths) * split_ratios[0])
    val_size = int(len(all_image_paths) * split_ratios[1])

    train_paths = all_image_paths[:train_size]
    val_paths = all_image_paths[train_size:train_size + val_size]
    test_paths = all_image_paths[train_size + val_size:]

    train_labels = all_labels[:train_size]
    val_labels = all_labels[train_size:train_size + val_size]
    test_labels = all_labels[train_size + val_size:]

    # Create datasets
    train_ds = create_dataset(train_paths, train_labels, preprocess_func)
    val_ds = create_dataset(val_paths, val_labels, preprocess_func)
    test_ds = create_dataset(test_paths, test_labels, preprocess_func)

    return train_ds, val_ds, test_ds


def create_resnet_regression_model(input_shape=(200, 200, 3)):
    base_model = ResNet101(include_top=False, weights='imagenet', input_tensor=Input(shape=input_shape))
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    output = Dense(1, activation='linear')(x)  # Single output neuron for regression
    model = Model(inputs=base_model.input, outputs=output)
    for layer in base_model.layers:
        layer.trainable = True
    return model

def compile_and_train_model(model, train_ds, val_ds, epochs=1):
    # Configure the checkpoint to save the best model
    checkpoint = ModelCheckpoint(
        f'best_model_elevations_resnet101_mse_lf.h5',  # Path where the model will be saved
        monitor='val_loss',  # Metric to monitor
        save_best_only=True,  # Save only the best model
        verbose=1  # Verbosity level
    )
    
    # Optional: Add early stopping to halt training when validation metric stops improving
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=50,  # Number of epochs with no improvement after which training will be stopped
        verbose=1
    )

    # Optional: Add TensorBoard to visualize training dynamics
    tensorboard = TensorBoard(log_dir='./elevation_logs')

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])


    # Train the model
    history = model.fit(
        train_ds,
        epochs=epochs,
        validation_data=val_ds,
        callbacks=[checkpoint, early_stopping, tensorboard]  # Include the checkpoint in the callbacks
    )
    
    return history


base_dir = '../data/raw_experimental_data'

evaluation_results = {
    'loss': [],
    'accuracy': []
}


train_ds, val_ds, test_ds = load_images_from_directory(
    base_dir, 
    lambda path: preprocess_image(path, (200, 200)), 
    split_ratios=(0.7, 0.2, 0.1)
)

model = create_resnet_regression_model()
history = compile_and_train_model(model, train_ds.batch(32), val_ds.batch(32), epochs=150)
# Out:
# 2024-04-29 22:03:15.172650: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-29 22:03:15.172705: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-29 22:03:15.265635: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-29 22:03:15.453134: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 22:03:16.449752: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-29 22:03:18.253707: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.541238: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.541679: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.543299: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.543465: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.543610: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.617995: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.618163: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.618317: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-29 22:03:18.618437: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13873 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:2b:00.0, compute capability: 8.9
# 2024-04-29 22:03:20.857470: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Epoch 1/150
# 2024-04-29 22:03:37.301052: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-04-29 22:03:37.604024: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-04-29 22:03:39.231085: I external/local_xla/xla/service/service.cc:168] XLA service 0x9e06600 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-29 22:03:39.231104: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2024-04-29 22:03:39.249107: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714449819.335862    8092 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2993/2993 [==============================] - ETA: 0s - loss: 52.6825 - mae: 4.8579
# Epoch 1: val_loss improved from inf to 24.21784, saving model to best_model_elevations_resnet101_mse_lf.h5
# /home/andrey/anaconda3/envs/A311/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2993/2993 [==============================] - 390s 118ms/step - loss: 52.6825 - mae: 4.8579 - val_loss: 24.2178 - val_mae: 3.5786
# Epoch 2/150
# 2993/2993 [==============================] - ETA: 0s - loss: 27.2681 - mae: 3.4627
# Epoch 2: val_loss improved from 24.21784 to 12.67787, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 353s 118ms/step - loss: 27.2681 - mae: 3.4627 - val_loss: 12.6779 - val_mae: 2.5757
# Epoch 3/150
# 2993/2993 [==============================] - ETA: 0s - loss: 15.5748 - mae: 2.5406
# Epoch 3: val_loss did not improve from 12.67787
# 2993/2993 [==============================] - 349s 117ms/step - loss: 15.5748 - mae: 2.5406 - val_loss: 13.7523 - val_mae: 2.5145
# Epoch 4/150
# 2993/2993 [==============================] - ETA: 0s - loss: 11.9632 - mae: 2.2006
# Epoch 4: val_loss did not improve from 12.67787
# 2993/2993 [==============================] - 345s 115ms/step - loss: 11.9632 - mae: 2.2006 - val_loss: 12.9159 - val_mae: 2.3910
# Epoch 5/150
# 2993/2993 [==============================] - ETA: 0s - loss: 8.9850 - mae: 1.9092
# Epoch 5: val_loss did not improve from 12.67787
# 2993/2993 [==============================] - 346s 116ms/step - loss: 8.9850 - mae: 1.9092 - val_loss: 12.6907 - val_mae: 2.6214
# Epoch 6/150
# 2993/2993 [==============================] - ETA: 0s - loss: 6.2867 - mae: 1.5519
# Epoch 6: val_loss did not improve from 12.67787
# 2993/2993 [==============================] - 347s 116ms/step - loss: 6.2867 - mae: 1.5519 - val_loss: 12.7240 - val_mae: 2.5666
# Epoch 7/150
# 2993/2993 [==============================] - ETA: 0s - loss: 6.5406 - mae: 1.5202
# Epoch 7: val_loss improved from 12.67787 to 7.50782, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 345s 115ms/step - loss: 6.5406 - mae: 1.5202 - val_loss: 7.5078 - val_mae: 1.6429
# Epoch 8/150
# 2993/2993 [==============================] - ETA: 0s - loss: 4.1385 - mae: 1.2269
# Epoch 8: val_loss improved from 7.50782 to 3.32462, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 4.1385 - mae: 1.2269 - val_loss: 3.3246 - val_mae: 1.1887
# Epoch 9/150
# 2993/2993 [==============================] - ETA: 0s - loss: 4.5192 - mae: 1.2112
# Epoch 9: val_loss improved from 3.32462 to 2.23951, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 346s 115ms/step - loss: 4.5192 - mae: 1.2112 - val_loss: 2.2395 - val_mae: 0.8336
# Epoch 10/150
# 2993/2993 [==============================] - ETA: 0s - loss: 3.3306 - mae: 1.0436
# Epoch 10: val_loss did not improve from 2.23951
# 2993/2993 [==============================] - 345s 115ms/step - loss: 3.3306 - mae: 1.0436 - val_loss: 4.5692 - val_mae: 1.2584
# Epoch 11/150
# 2993/2993 [==============================] - ETA: 0s - loss: 3.2642 - mae: 1.0292
# Epoch 11: val_loss did not improve from 2.23951
# 2993/2993 [==============================] - 348s 116ms/step - loss: 3.2642 - mae: 1.0292 - val_loss: 19.3836 - val_mae: 2.4302
# Epoch 12/150
# 2993/2993 [==============================] - ETA: 0s - loss: 3.1379 - mae: 0.9756
# Epoch 12: val_loss improved from 2.23951 to 1.86356, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 3.1379 - mae: 0.9756 - val_loss: 1.8636 - val_mae: 0.6974
# Epoch 13/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.8635 - mae: 0.7884
# Epoch 13: val_loss did not improve from 1.86356
# 2993/2993 [==============================] - 345s 115ms/step - loss: 1.8635 - mae: 0.7884 - val_loss: 20.5514 - val_mae: 1.6539
# Epoch 14/150
# 2993/2993 [==============================] - ETA: 0s - loss: 2.7940 - mae: 0.9073
# Epoch 14: val_loss did not improve from 1.86356
# 2993/2993 [==============================] - 345s 115ms/step - loss: 2.7940 - mae: 0.9073 - val_loss: 1.9902 - val_mae: 0.6737
# Epoch 15/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.8413 - mae: 0.7319
# Epoch 15: val_loss did not improve from 1.86356
# 2993/2993 [==============================] - 345s 115ms/step - loss: 1.8413 - mae: 0.7319 - val_loss: 2.0158 - val_mae: 0.6979
# Epoch 16/150
# 2993/2993 [==============================] - ETA: 0s - loss: 2.9667 - mae: 0.8804
# Epoch 16: val_loss improved from 1.86356 to 1.53518, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 346s 116ms/step - loss: 2.9667 - mae: 0.8804 - val_loss: 1.5352 - val_mae: 0.6244
# Epoch 17/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.9443 - mae: 0.5496
# Epoch 17: val_loss improved from 1.53518 to 1.49086, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.9443 - mae: 0.5496 - val_loss: 1.4909 - val_mae: 0.6718
# Epoch 18/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.8283 - mae: 0.6623
# Epoch 18: val_loss improved from 1.49086 to 1.23199, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 1.8283 - mae: 0.6623 - val_loss: 1.2320 - val_mae: 0.4514
# Epoch 19/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.4744 - mae: 0.6160
# Epoch 19: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 346s 116ms/step - loss: 1.4744 - mae: 0.6160 - val_loss: 39.5690 - val_mae: 2.7803
# Epoch 20/150
# 2993/2993 [==============================] - ETA: 0s - loss: 2.1748 - mae: 0.7192
# Epoch 20: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 345s 115ms/step - loss: 2.1748 - mae: 0.7192 - val_loss: 1.5860 - val_mae: 0.6482
# Epoch 21/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.5224 - mae: 0.6043
# Epoch 21: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 346s 116ms/step - loss: 1.5224 - mae: 0.6043 - val_loss: 2.0577 - val_mae: 0.6249
# Epoch 22/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.8233 - mae: 0.6401
# Epoch 22: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 346s 116ms/step - loss: 1.8233 - mae: 0.6401 - val_loss: 1.5033 - val_mae: 0.4957
# Epoch 23/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.0519 - mae: 0.5080
# Epoch 23: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 345s 115ms/step - loss: 1.0519 - mae: 0.5080 - val_loss: 3.8947 - val_mae: 0.8580
# Epoch 24/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.1935 - mae: 0.5476
# Epoch 24: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 345s 115ms/step - loss: 1.1935 - mae: 0.5476 - val_loss: 1.3234 - val_mae: 0.4444
# Epoch 25/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.4418 - mae: 0.5726
# Epoch 25: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 347s 116ms/step - loss: 1.4418 - mae: 0.5726 - val_loss: 1.3774 - val_mae: 0.5185
# Epoch 26/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.9773 - mae: 0.4849
# Epoch 26: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.9773 - mae: 0.4849 - val_loss: 1.4763 - val_mae: 0.4977
# Epoch 27/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.7537 - mae: 0.4287
# Epoch 27: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.7537 - mae: 0.4287 - val_loss: 1.5470 - val_mae: 0.4386
# Epoch 28/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.0162 - mae: 0.4777
# Epoch 28: val_loss did not improve from 1.23199
# 2993/2993 [==============================] - 345s 115ms/step - loss: 1.0162 - mae: 0.4777 - val_loss: 1.5174 - val_mae: 0.6175
# Epoch 29/150
# 2993/2993 [==============================] - ETA: 0s - loss: 1.3851 - mae: 0.5085
# Epoch 29: val_loss improved from 1.23199 to 1.09857, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 1.3851 - mae: 0.5085 - val_loss: 1.0986 - val_mae: 0.3831
# Epoch 30/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.8076 - mae: 0.4179
# Epoch 30: val_loss did not improve from 1.09857
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.8076 - mae: 0.4179 - val_loss: 1.2865 - val_mae: 0.6448
# Epoch 31/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.8470 - mae: 0.4194
# Epoch 31: val_loss did not improve from 1.09857
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.8470 - mae: 0.4194 - val_loss: 1.2384 - val_mae: 0.4574
# Epoch 32/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.6863 - mae: 0.3880
# Epoch 32: val_loss improved from 1.09857 to 0.81986, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.6863 - mae: 0.3880 - val_loss: 0.8199 - val_mae: 0.3657
# Epoch 33/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.6442 - mae: 0.3828
# Epoch 33: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.6442 - mae: 0.3828 - val_loss: 2.3493 - val_mae: 0.7025
# Epoch 34/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.9277 - mae: 0.4177
# Epoch 34: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.9277 - mae: 0.4177 - val_loss: 1.8035 - val_mae: 0.7949
# Epoch 35/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5889 - mae: 0.3572
# Epoch 35: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.5889 - mae: 0.3572 - val_loss: 0.8871 - val_mae: 0.4028
# Epoch 36/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.9853 - mae: 0.4320
# Epoch 36: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.9853 - mae: 0.4320 - val_loss: 1.9644 - val_mae: 0.4918
# Epoch 37/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4476 - mae: 0.3258
# Epoch 37: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.4476 - mae: 0.3258 - val_loss: 1.2686 - val_mae: 0.3955
# Epoch 38/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.7171 - mae: 0.3586
# Epoch 38: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.7171 - mae: 0.3586 - val_loss: 2.9946 - val_mae: 0.6611
# Epoch 39/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5825 - mae: 0.3370
# Epoch 39: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.5825 - mae: 0.3370 - val_loss: 1.5151 - val_mae: 0.5664
# Epoch 40/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3633 - mae: 0.2866
# Epoch 40: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.3633 - mae: 0.2866 - val_loss: 5.5431 - val_mae: 0.7734
# Epoch 41/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4824 - mae: 0.3273
# Epoch 41: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.4824 - mae: 0.3273 - val_loss: 1.0957 - val_mae: 0.3167
# Epoch 42/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.6650 - mae: 0.3560
# Epoch 42: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.6650 - mae: 0.3560 - val_loss: 1.1362 - val_mae: 0.3736
# Epoch 43/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.7231 - mae: 0.3617
# Epoch 43: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.7231 - mae: 0.3617 - val_loss: 0.9722 - val_mae: 0.6196
# Epoch 44/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4700 - mae: 0.3066
# Epoch 44: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.4700 - mae: 0.3066 - val_loss: 1.7810 - val_mae: 0.4733
# Epoch 45/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4309 - mae: 0.2950
# Epoch 45: val_loss did not improve from 0.81986
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.4309 - mae: 0.2950 - val_loss: 0.9467 - val_mae: 0.2882
# Epoch 46/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5055 - mae: 0.3047
# Epoch 46: val_loss improved from 0.81986 to 0.62573, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 349s 117ms/step - loss: 0.5055 - mae: 0.3047 - val_loss: 0.6257 - val_mae: 0.2306
# Epoch 47/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2857 - mae: 0.2458
# Epoch 47: val_loss did not improve from 0.62573
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.2857 - mae: 0.2458 - val_loss: 2.9829 - val_mae: 0.5535
# Epoch 48/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4916 - mae: 0.3074
# Epoch 48: val_loss improved from 0.62573 to 0.61612, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.4916 - mae: 0.3074 - val_loss: 0.6161 - val_mae: 0.3551
# Epoch 49/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3682 - mae: 0.2754
# Epoch 49: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.3682 - mae: 0.2754 - val_loss: 5.1825 - val_mae: 0.8752
# Epoch 50/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5057 - mae: 0.3014
# Epoch 50: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.5057 - mae: 0.3014 - val_loss: 1.1002 - val_mae: 0.2979
# Epoch 51/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4667 - mae: 0.3122
# Epoch 51: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.4667 - mae: 0.3122 - val_loss: 1.7689 - val_mae: 0.5819
# Epoch 52/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4064 - mae: 0.2991
# Epoch 52: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.4064 - mae: 0.2991 - val_loss: 2.0281 - val_mae: 0.4530
# Epoch 53/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.7910 - mae: 0.3623
# Epoch 53: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 346s 115ms/step - loss: 0.7910 - mae: 0.3623 - val_loss: 0.7011 - val_mae: 0.2261
# Epoch 54/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5957 - mae: 0.3077
# Epoch 54: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.5957 - mae: 0.3077 - val_loss: 1.1269 - val_mae: 0.2897
# Epoch 55/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5542 - mae: 0.2971
# Epoch 55: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.5542 - mae: 0.2971 - val_loss: 0.9333 - val_mae: 0.3515
# Epoch 56/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2600 - mae: 0.2241
# Epoch 56: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.2600 - mae: 0.2241 - val_loss: 0.9413 - val_mae: 0.2646
# Epoch 57/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3853 - mae: 0.2475
# Epoch 57: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.3853 - mae: 0.2475 - val_loss: 0.8013 - val_mae: 0.3534
# Epoch 58/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3068 - mae: 0.2328
# Epoch 58: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.3068 - mae: 0.2328 - val_loss: 1.1845 - val_mae: 0.4305
# Epoch 59/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5008 - mae: 0.2802
# Epoch 59: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.5008 - mae: 0.2802 - val_loss: 1.2866 - val_mae: 0.3060
# Epoch 60/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3530 - mae: 0.2500
# Epoch 60: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.3530 - mae: 0.2500 - val_loss: 0.6776 - val_mae: 0.2459
# Epoch 61/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2710 - mae: 0.2264
# Epoch 61: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.2710 - mae: 0.2264 - val_loss: 1.2214 - val_mae: 0.4204
# Epoch 62/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3378 - mae: 0.2450
# Epoch 62: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.3378 - mae: 0.2450 - val_loss: 6.9981 - val_mae: 0.8043
# Epoch 63/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3264 - mae: 0.2493
# Epoch 63: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.3264 - mae: 0.2493 - val_loss: 0.8905 - val_mae: 0.2930
# Epoch 64/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4176 - mae: 0.2810
# Epoch 64: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.4176 - mae: 0.2810 - val_loss: 0.6162 - val_mae: 0.2420
# Epoch 65/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2503 - mae: 0.2287
# Epoch 65: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.2503 - mae: 0.2287 - val_loss: 0.8389 - val_mae: 0.3368
# Epoch 66/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2479 - mae: 0.2262
# Epoch 66: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 348s 116ms/step - loss: 0.2479 - mae: 0.2262 - val_loss: 0.8909 - val_mae: 0.3301
# Epoch 67/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5377 - mae: 0.3074
# Epoch 67: val_loss did not improve from 0.61612
# 2993/2993 [==============================] - 346s 115ms/step - loss: 0.5377 - mae: 0.3074 - val_loss: 0.7781 - val_mae: 0.2774
# Epoch 68/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2239 - mae: 0.2286
# Epoch 68: val_loss improved from 0.61612 to 0.48092, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.2239 - mae: 0.2286 - val_loss: 0.4809 - val_mae: 0.1732
# Epoch 69/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3718 - mae: 0.2507
# Epoch 69: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.3718 - mae: 0.2507 - val_loss: 2.1116 - val_mae: 0.4727
# Epoch 70/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4439 - mae: 0.2759
# Epoch 70: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.4439 - mae: 0.2759 - val_loss: 0.6033 - val_mae: 0.1779
# Epoch 71/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1582 - mae: 0.1804
# Epoch 71: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.1582 - mae: 0.1804 - val_loss: 0.5670 - val_mae: 0.1806
# Epoch 72/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3600 - mae: 0.2348
# Epoch 72: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 346s 115ms/step - loss: 0.3600 - mae: 0.2348 - val_loss: 0.7220 - val_mae: 0.2268
# Epoch 73/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1383 - mae: 0.1665
# Epoch 73: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.1383 - mae: 0.1665 - val_loss: 0.5617 - val_mae: 0.1638
# Epoch 74/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4607 - mae: 0.2628
# Epoch 74: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.4607 - mae: 0.2628 - val_loss: 0.5534 - val_mae: 0.2082
# Epoch 75/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1878 - mae: 0.1931
# Epoch 75: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1878 - mae: 0.1931 - val_loss: 4.1877 - val_mae: 0.5931
# Epoch 76/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.4338 - mae: 0.2598
# Epoch 76: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.4338 - mae: 0.2598 - val_loss: 0.7136 - val_mae: 0.2031
# Epoch 77/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1431 - mae: 0.1696
# Epoch 77: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1431 - mae: 0.1696 - val_loss: 1.1313 - val_mae: 0.4226
# Epoch 78/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2178 - mae: 0.1948
# Epoch 78: val_loss did not improve from 0.48092
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.2178 - mae: 0.1948 - val_loss: 0.6340 - val_mae: 0.1863
# Epoch 79/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2448 - mae: 0.2060
# Epoch 79: val_loss improved from 0.48092 to 0.41747, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.2448 - mae: 0.2060 - val_loss: 0.4175 - val_mae: 0.1670
# Epoch 80/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1884 - mae: 0.1959
# Epoch 80: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.1884 - mae: 0.1959 - val_loss: 0.7824 - val_mae: 0.3934
# Epoch 81/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2250 - mae: 0.2229
# Epoch 81: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.2250 - mae: 0.2229 - val_loss: 0.8549 - val_mae: 0.3265
# Epoch 82/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2974 - mae: 0.2687
# Epoch 82: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 346s 115ms/step - loss: 0.2974 - mae: 0.2687 - val_loss: 0.4997 - val_mae: 0.2255
# Epoch 83/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1752 - mae: 0.2186
# Epoch 83: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.1752 - mae: 0.2186 - val_loss: 1.2926 - val_mae: 0.4089
# Epoch 84/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.3032 - mae: 0.2401
# Epoch 84: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.3032 - mae: 0.2401 - val_loss: 0.8741 - val_mae: 0.3172
# Epoch 85/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2162 - mae: 0.2095
# Epoch 85: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.2162 - mae: 0.2095 - val_loss: 0.6676 - val_mae: 0.1871
# Epoch 86/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.5028 - mae: 0.2614
# Epoch 86: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.5028 - mae: 0.2614 - val_loss: 0.4845 - val_mae: 0.1702
# Epoch 87/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1538 - mae: 0.1649
# Epoch 87: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 346s 115ms/step - loss: 0.1538 - mae: 0.1649 - val_loss: 2.2992 - val_mae: 0.4052
# Epoch 88/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2517 - mae: 0.1979
# Epoch 88: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.2517 - mae: 0.1979 - val_loss: 0.8462 - val_mae: 0.4101
# Epoch 89/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1711 - mae: 0.1738
# Epoch 89: val_loss did not improve from 0.41747
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.1711 - mae: 0.1738 - val_loss: 0.8222 - val_mae: 0.3372
# Epoch 90/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2461 - mae: 0.2051
# Epoch 90: val_loss improved from 0.41747 to 0.38705, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.2461 - mae: 0.2051 - val_loss: 0.3870 - val_mae: 0.1484
# Epoch 91/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1743 - mae: 0.1799
# Epoch 91: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1743 - mae: 0.1799 - val_loss: 0.5236 - val_mae: 0.2377
# Epoch 92/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1549 - mae: 0.1754
# Epoch 92: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1549 - mae: 0.1754 - val_loss: 0.4331 - val_mae: 0.1706
# Epoch 93/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2687 - mae: 0.2419
# Epoch 93: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.2687 - mae: 0.2419 - val_loss: 0.4732 - val_mae: 0.3349
# Epoch 94/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2296 - mae: 0.2311
# Epoch 94: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.2296 - mae: 0.2311 - val_loss: 1.4221 - val_mae: 0.3406
# Epoch 95/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2242 - mae: 0.1854
# Epoch 95: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 353s 118ms/step - loss: 0.2242 - mae: 0.1854 - val_loss: 0.5780 - val_mae: 0.2025
# Epoch 96/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.0816 - mae: 0.1327
# Epoch 96: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 351s 117ms/step - loss: 0.0816 - mae: 0.1327 - val_loss: 0.4050 - val_mae: 0.1403
# Epoch 97/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2766 - mae: 0.2079
# Epoch 97: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 351s 117ms/step - loss: 0.2766 - mae: 0.2079 - val_loss: 0.5793 - val_mae: 0.2671
# Epoch 98/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2955 - mae: 0.2163
# Epoch 98: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.2955 - mae: 0.2163 - val_loss: 0.7674 - val_mae: 0.3059
# Epoch 99/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1699 - mae: 0.1906
# Epoch 99: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.1699 - mae: 0.1906 - val_loss: 0.8080 - val_mae: 0.2168
# Epoch 100/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2373 - mae: 0.2212
# Epoch 100: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 352s 118ms/step - loss: 0.2373 - mae: 0.2212 - val_loss: 0.6734 - val_mae: 0.2998
# Epoch 101/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1699 - mae: 0.1967
# Epoch 101: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 353s 118ms/step - loss: 0.1699 - mae: 0.1967 - val_loss: 0.4559 - val_mae: 0.2725
# Epoch 102/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1852 - mae: 0.1740
# Epoch 102: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 349s 117ms/step - loss: 0.1852 - mae: 0.1740 - val_loss: 0.7503 - val_mae: 0.2073
# Epoch 103/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1758 - mae: 0.1703
# Epoch 103: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.1758 - mae: 0.1703 - val_loss: 0.5616 - val_mae: 0.2647
# Epoch 104/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1428 - mae: 0.1621
# Epoch 104: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.1428 - mae: 0.1621 - val_loss: 0.5493 - val_mae: 0.2850
# Epoch 105/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1890 - mae: 0.2128
# Epoch 105: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1890 - mae: 0.2128 - val_loss: 0.5489 - val_mae: 0.3613
# Epoch 106/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2254 - mae: 0.2415
# Epoch 106: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.2254 - mae: 0.2415 - val_loss: 0.6677 - val_mae: 0.2451
# Epoch 107/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1963 - mae: 0.2003
# Epoch 107: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1963 - mae: 0.2003 - val_loss: 0.7796 - val_mae: 0.2962
# Epoch 108/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.0946 - mae: 0.1459
# Epoch 108: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.0946 - mae: 0.1459 - val_loss: 0.4924 - val_mae: 0.3753
# Epoch 109/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1733 - mae: 0.1634
# Epoch 109: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1733 - mae: 0.1634 - val_loss: 0.6553 - val_mae: 0.2936
# Epoch 110/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1351 - mae: 0.1612
# Epoch 110: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1351 - mae: 0.1612 - val_loss: 0.6221 - val_mae: 0.3267
# Epoch 111/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1376 - mae: 0.1715
# Epoch 111: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1376 - mae: 0.1715 - val_loss: 0.5310 - val_mae: 0.2236
# Epoch 112/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2332 - mae: 0.2431
# Epoch 112: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.2332 - mae: 0.2431 - val_loss: 0.5002 - val_mae: 0.1911
# Epoch 113/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1747 - mae: 0.2079
# Epoch 113: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.1747 - mae: 0.2079 - val_loss: 1.1254 - val_mae: 0.3118
# Epoch 114/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1866 - mae: 0.1762
# Epoch 114: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.1866 - mae: 0.1762 - val_loss: 2.3018 - val_mae: 0.4092
# Epoch 115/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1133 - mae: 0.1486
# Epoch 115: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1133 - mae: 0.1486 - val_loss: 0.9968 - val_mae: 0.2988
# Epoch 116/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1604 - mae: 0.1665
# Epoch 116: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1604 - mae: 0.1665 - val_loss: 0.3959 - val_mae: 0.1345
# Epoch 117/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1783 - mae: 0.1939
# Epoch 117: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1783 - mae: 0.1939 - val_loss: 0.6167 - val_mae: 0.2824
# Epoch 118/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2211 - mae: 0.2385
# Epoch 118: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.2211 - mae: 0.2385 - val_loss: 0.6641 - val_mae: 0.4087
# Epoch 119/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1196 - mae: 0.1890
# Epoch 119: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1196 - mae: 0.1890 - val_loss: 0.5661 - val_mae: 0.1561
# Epoch 120/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2350 - mae: 0.1709
# Epoch 120: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.2350 - mae: 0.1709 - val_loss: 0.8077 - val_mae: 0.1714
# Epoch 121/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1075 - mae: 0.1370
# Epoch 121: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1075 - mae: 0.1370 - val_loss: 0.4407 - val_mae: 0.1981
# Epoch 122/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1395 - mae: 0.1505
# Epoch 122: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1395 - mae: 0.1505 - val_loss: 0.6010 - val_mae: 0.2167
# Epoch 123/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1950 - mae: 0.1829
# Epoch 123: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1950 - mae: 0.1829 - val_loss: 0.5758 - val_mae: 0.2559
# Epoch 124/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1781 - mae: 0.2276
# Epoch 124: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1781 - mae: 0.2276 - val_loss: 0.5636 - val_mae: 0.3244
# Epoch 125/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1563 - mae: 0.1853
# Epoch 125: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.1563 - mae: 0.1853 - val_loss: 0.5461 - val_mae: 0.3289
# Epoch 126/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1195 - mae: 0.1568
# Epoch 126: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1195 - mae: 0.1568 - val_loss: 0.4286 - val_mae: 0.1734
# Epoch 127/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1015 - mae: 0.1440
# Epoch 127: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1015 - mae: 0.1440 - val_loss: 0.5168 - val_mae: 0.1515
# Epoch 128/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1845 - mae: 0.1772
# Epoch 128: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1845 - mae: 0.1772 - val_loss: 0.9948 - val_mae: 0.3436
# Epoch 129/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1911 - mae: 0.2197
# Epoch 129: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1911 - mae: 0.2197 - val_loss: 0.6139 - val_mae: 0.2568
# Epoch 130/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2559 - mae: 0.2298
# Epoch 130: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.2559 - mae: 0.2298 - val_loss: 0.5920 - val_mae: 0.2539
# Epoch 131/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1581 - mae: 0.1638
# Epoch 131: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 346s 115ms/step - loss: 0.1581 - mae: 0.1638 - val_loss: 0.9309 - val_mae: 0.2088
# Epoch 132/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1264 - mae: 0.1280
# Epoch 132: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1264 - mae: 0.1280 - val_loss: 0.5308 - val_mae: 0.2130
# Epoch 133/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1448 - mae: 0.1500
# Epoch 133: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1448 - mae: 0.1500 - val_loss: 1.1836 - val_mae: 0.4651
# Epoch 134/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.0988 - mae: 0.1338
# Epoch 134: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.0988 - mae: 0.1338 - val_loss: 0.4576 - val_mae: 0.2264
# Epoch 135/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.0725 - mae: 0.1299
# Epoch 135: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.0725 - mae: 0.1299 - val_loss: 0.4262 - val_mae: 0.1712
# Epoch 136/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1548 - mae: 0.1845
# Epoch 136: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1548 - mae: 0.1845 - val_loss: 0.6240 - val_mae: 0.4452
# Epoch 137/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1887 - mae: 0.2157
# Epoch 137: val_loss did not improve from 0.38705
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.1887 - mae: 0.2157 - val_loss: 0.4307 - val_mae: 0.1550
# Epoch 138/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.0907 - mae: 0.1512
# Epoch 138: val_loss improved from 0.38705 to 0.36712, saving model to best_model_elevations_resnet101_mse_lf.h5
# 2993/2993 [==============================] - 347s 116ms/step - loss: 0.0907 - mae: 0.1512 - val_loss: 0.3671 - val_mae: 0.2643
# Epoch 139/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1564 - mae: 0.1511
# Epoch 139: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.1564 - mae: 0.1511 - val_loss: 0.6700 - val_mae: 0.4435
# Epoch 140/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1764 - mae: 0.1468
# Epoch 140: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 346s 116ms/step - loss: 0.1764 - mae: 0.1468 - val_loss: 0.3891 - val_mae: 0.2713
# Epoch 141/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.0833 - mae: 0.1189
# Epoch 141: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.0833 - mae: 0.1189 - val_loss: 0.5260 - val_mae: 0.2013
# Epoch 142/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1064 - mae: 0.1429
# Epoch 142: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1064 - mae: 0.1429 - val_loss: 0.4281 - val_mae: 0.3226
# Epoch 143/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1383 - mae: 0.1712
# Epoch 143: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1383 - mae: 0.1712 - val_loss: 0.3800 - val_mae: 0.1344
# Epoch 144/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1972 - mae: 0.2265
# Epoch 144: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 344s 115ms/step - loss: 0.1972 - mae: 0.2265 - val_loss: 0.4268 - val_mae: 0.1425
# Epoch 145/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1514 - mae: 0.1897
# Epoch 145: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1514 - mae: 0.1897 - val_loss: 0.3982 - val_mae: 0.1296
# Epoch 146/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.2148 - mae: 0.1955
# Epoch 146: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.2148 - mae: 0.1955 - val_loss: 0.7698 - val_mae: 0.2762
# Epoch 147/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1380 - mae: 0.1455
# Epoch 147: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1380 - mae: 0.1455 - val_loss: 0.5617 - val_mae: 0.1531
# Epoch 148/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1309 - mae: 0.1385
# Epoch 148: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1309 - mae: 0.1385 - val_loss: 0.4435 - val_mae: 0.1397
# Epoch 149/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1450 - mae: 0.1483
# Epoch 149: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1450 - mae: 0.1483 - val_loss: 0.4486 - val_mae: 0.1774
# Epoch 150/150
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1563 - mae: 0.1586
# Epoch 150: val_loss did not improve from 0.36712
# 2993/2993 [==============================] - 345s 115ms/step - loss: 0.1563 - mae: 0.1586 - val_loss: 0.5120 - val_mae: 0.1482

# %%
best_model = load_model(f'best_model_elevations_resnet101_mse_lf.h5')

results = best_model.evaluate(test_ds.batch(32), verbose=1)
evaluation_results['loss'].append(results[0])
evaluation_results['accuracy'].append(results[1])
# Out:
# 428/428 [==============================] - 16s 35ms/step - loss: 0.6747 - mae: 0.2782

# %% [markdown]
# evaluation_results

# %%
evaluation_results = {
    'zones': [],
    'loss': [],
    'accuracy': []
}

zone_divisions = [4, 6, 12, 18, 36, 72, 120, 180, 360]
for zone in zone_divisions:
    
    train_ds, val_ds, test_ds = load_images_from_directory(
        base_dir, 
        lambda path: preprocess_image(path, (200, 200)), 
        split_ratios=(0.7, 0.2, 0.1),
        zones = zone,
    )
    
    
    
    best_model = load_model(f'az_models_densenet/best_model_zones_{zone}.h5')

    results = best_model.evaluate(test_ds.batch(32), verbose=1)
    evaluation_results['zones'].append(zone)
    evaluation_results['loss'].append(results[0])
    evaluation_results['accuracy'].append(results[1])

# %%
real_image_paths = ["/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3703.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3704.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3705.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3706.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4090.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4091.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4092.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4096.png", 
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4097.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4098.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4099.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4100.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4101.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4102.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4103.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4104.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4105.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4106.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4107.png"]
real_elevation_labels = [0, 0, 45, 45, 0, 0, 0, 75, 75, 75, 0, 0, 75, 0, 0, 0, 0, 0, 0]  # Dummy elevation values
real_azimuth_labels = [105, 250, 275, 305, 100, 3, 280, 90, 40, 135, 175, 268, 267, 95, 45, 285, 330, 1, 90]  # Dummy azimuth values

def preprocess_real_images(image_path):
    # This assumes the preprocess function and grayscale conversion are correctly defined
    rgb_image = tf.io.read_file(image_path)
    rgb_image = tf.image.decode_png(rgb_image, channels=3)  # Adjust if images are not PNG
    rgb_image = tf.image.resize(rgb_image, [200, 200])
    rgb_image = rgb_image / 255.0  # Normalize to [0,1]
    return rgb_image  # Assuming this function is defined

def preprocess_image(image_path):
    """Load and preprocess an image."""
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)  # Assuming images are in PNG format
    image = tf.image.resize(image, [200, 200])  # Resize to the desired size for your model
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image  # Here, keep it in RGB if that's what the model expects

def create_tf_dataset(image_paths, elevation_labels, azimuth_labels):
    """Create a TensorFlow dataset from image paths and labels."""
    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices({
        'elevation': tf.cast(elevation_labels, tf.int64),
        'azimuth': tf.cast(azimuth_labels, tf.int64)  // (360)
    })

    # Combine into a single dataset
    dataset = tf.data.Dataset.zip((image_ds, labels_ds))
    return dataset

real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)
real_dataset = real_dataset.batch(32)  # Batch the dataset for model evaluation or visualization

# %%
import matplotlib.pyplot as plt

def predict_and_visualize(model, dataset, sample_size=24):
    """
    Predicts using the model on the dataset and visualizes the results in a vertical layout.
    
    Args:
    model (tf.keras.Model): The trained model.
    dataset (tf.data.Dataset): The dataset for prediction.
    sample_size (int): Number of predictions to visualize.
    """
    # Take samples for prediction
    sample_dataset = dataset.take(sample_size)
    
    # Since the dataset is batched, predictions and visualization must handle batches
    for images, labels in sample_dataset:  # Iterate over batches
        predictions = model.predict(images)  # Predict a whole batch

        plt.figure(figsize=(6, 2 * sample_size))  # Adjust the figure size for vertical layout
        plt.suptitle('Predictions', fontsize=16)

        for i, image in enumerate(images):  # Now iterate over images in the batch
            plt.subplot(sample_size, 1, i + 1)  # Change subplot to arrange images vertically
            predicted_label = np.argmax(predictions[i])
            plt.imshow(image.numpy().squeeze(), cmap='gray')  # Adjust color mapping if necessary
            plt.title(f"Predicted Label: {predicted_label}", fontsize=14)  # Adjust font size
            plt.axis('off')

        plt.subplots_adjust(hspace=0.5)  # Adjust the horizontal spacing between subplots
        plt.show()

# Example of how to call the function
predict_and_visualize(best_model, real_dataset)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
real_image_paths = ["/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3703.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3704.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3705.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3706.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4090.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4091.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4092.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4096.png", 
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4097.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4098.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4099.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4100.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4101.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4102.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4103.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4104.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4105.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4106.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4107.png"]
real_elevation_labels = [0, 0, 45, 45, 0, 0, 0, 75, 75, 75, 0, 0, 75, 0, 0, 0, 0, 0, 0]  # Dummy elevation values
real_azimuth_labels = [105, 250, 275, 305, 100, 3, 280, 90, 40, 135, 175, 268, 267, 95, 45, 285, 330, 1, 90]  # Dummy azimuth values
import tensorflow as tf
import numpy as np
import tensorflow as tf
import numpy as np

import tensorflow as tf
import numpy as np

def preprocess_real_images(image_path):
    # This assumes the preprocess function and grayscale conversion are correctly defined
    rgb_image = tf.io.read_file(image_path)
    rgb_image = tf.image.decode_png(rgb_image, channels=3)  # Adjust if images are not PNG
    rgb_image = tf.image.resize(rgb_image, [200, 200])
    rgb_image = rgb_image / 255.0  # Normalize to [0,1]
    return rgb_to_three_channel_grayscale(rgb_image)  # Assuming this function is defined

def rgb_to_three_channel_grayscale(image):
    """Convert an RGB image to 3-channel grayscale."""
    grayscale = tf.image.rgb_to_grayscale(image)
    grayscale = tf.tile(grayscale, [1, 1, 3])  # Repeat the grayscale channel three times
    return grayscale

def preprocess_image(image_path):
    """Load and preprocess an image."""
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)  # Assuming images are in PNG format
    image = tf.image.resize(image, [200, 200])  # Resize to the desired size for your model
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image  # Here, keep it in RGB if that's what the model expects

def create_tf_dataset(image_paths, elevation_labels, azimuth_labels):
    """Create a TensorFlow dataset from image paths and labels."""
    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices({
        'elevation': tf.cast(elevation_labels, tf.int64),
        'azimuth': tf.cast(azimuth_labels, tf.int64)  // (360/zones)
    })

    # Combine into a single dataset
    dataset = tf.data.Dataset.zip((image_ds, labels_ds))
    return dataset

real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)
real_dataset = real_dataset.batch(32)  # Batch the dataset for model evaluation or visualization
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 55
#      52     dataset = tf.data.Dataset.zip((image_ds, labels_ds))
#      53     return dataset
# ---> 55 real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)
#      56 real_dataset = real_dataset.batch(32)  # Batch the dataset for model evaluation or visualization
#
# Cell In[5], line 48, in create_tf_dataset(image_paths, elevation_labels, azimuth_labels)
#      44 """Create a TensorFlow dataset from image paths and labels."""
#      45 image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
#      46 labels_ds = tf.data.Dataset.from_tensor_slices({
#      47     'elevation': tf.cast(elevation_labels, tf.int64),
# ---> 48     'azimuth': tf.cast(azimuth_labels, tf.int64)  // (360/zones)
#      49 })
#      51 # Combine into a single dataset
#      52 dataset = tf.data.Dataset.zip((image_ds, labels_ds))
#
# NameError: name 'zones' is not defined

# %%
test_ds

# %%
real_dataset

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_samples_with_predictions(dataset, model, title, num_samples=3):
    plt.figure(figsize=(15, 5))
    plt.suptitle(title, fontsize=16)
    
    for images, labels in dataset.take(1):  # Take one batch from the dataset
        if images.shape[0] < num_samples:
            raise ValueError("Not enough samples in the batch. Increase batch size or reduce num_samples.")
        
        # Get model predictions
        predictions = model.predict(images)
        predicted_labels = np.argmax(predictions, axis=1)  # Assuming model outputs logits or softmax
        
        for i in range(num_samples):
            plt.subplot(1, num_samples, i + 1)
            plt.imshow(images[i].numpy())
            
            # Adjust how labels are accessed based on your dataset structure
            # Check if labels are a dictionary and adjust accordingly
            if isinstance(labels, dict):
                actual_label = f"Elevation: {labels['elevation'][i].numpy()}, Azimuth: {labels['azimuth'][i].numpy()}"
            else:
                actual_label = labels[i].numpy()
                
            predicted_label = predicted_labels[i]
            plt.title(f"True: {actual_label}\nPred: {predicted_label}")
            plt.axis('off')
    plt.show()

# Example usage, make sure the model and datasets are correctly configured
batch_size = 3
plot_samples_with_predictions(real_dataset.batch(batch_size), model, "Real Dataset")

# Ensure the model is correctly loaded and compiled
# Assuming `model` is your loaded and compiled model and the datasets are batched

plot_samples_with_predictions(train_ds.batch(batch_size), model, "Training Samples")
plot_samples_with_predictions(val_ds.batch(batch_size), model, "Validation Samples")
plot_samples_with_predictions(test_ds.batch(batch_size), model, "Test Samples")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 35
#      33 # Example usage, make sure the model and datasets are correctly configured
#      34 batch_size = 3
# ---> 35 plot_samples_with_predictions(real_dataset.batch(batch_size), model, "Real Dataset")
#      37 # Ensure the model is correctly loaded and compiled
#      38 # Assuming `model` is your loaded and compiled model and the datasets are batched
#      40 plot_samples_with_predictions(train_ds.batch(batch_size), model, "Training Samples")
#
# Cell In[6], line 11, in plot_samples_with_predictions(dataset, model, title, num_samples)
#       9 for images, labels in dataset.take(1):  # Take one batch from the dataset
#      10     if images.shape[0] < num_samples:
# ---> 11         raise ValueError("Not enough samples in the batch. Increase batch size or reduce num_samples.")
#      13     # Get model predictions
#      14     predictions = model.predict(images)
#
# ValueError: Not enough samples in the batch. Increase batch size or reduce num_samples.

# %%
real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)

# Example of how to check dataset structure
for images, labels in real_dataset.take(1):
    print(f"Image shape: {images.shape}, Label: {labels}")

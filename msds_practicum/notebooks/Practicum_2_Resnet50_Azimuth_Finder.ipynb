# %%
import os
import re
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Conv2D, UpSampling2D, BatchNormalization, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.keras.applications import DenseNet121
from functools import reduce
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam


def rgb_to_three_channel_grayscale(image):
    grayscale_image = tf.image.rgb_to_grayscale(image)
    return tf.repeat(grayscale_image, repeats=3, axis=-1)

def preprocess_image(rgb_path, target_size=(200, 200)):
    rgb_image = tf.io.read_file(rgb_path)
    rgb_image = tf.image.decode_png(rgb_image, channels=3)
    rgb_image = tf.image.resize(rgb_image, target_size)
    return rgb_image / 255.0

def parse_image_filename(filename, zones):
    match = re.search(r'image\.(\d+)\.rgb\.png', filename)
    if match:
        azimuth = int(match.group(1)) % 360
        return azimuth // (360 // zones)
    return 0

def split_dataset(data, split_ratios=(0.8, 0.1, 0.1)):
    indices = np.random.permutation(len(data))
    split1 = int(split_ratios[0] * len(data))
    split2 = split1 + int(split_ratios[1] * len(data))
    return [data[i] for i in indices[:split1]], [data[i] for i in indices[split1:split2]], [data[i] for i in indices[split2:]]

def create_dataset(image_paths, labels, preprocess_func):
    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_func, num_parallel_calls=tf.data.AUTOTUNE)
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((image_ds, label_ds))

def load_images_from_directory(base_dir, preprocess_func, split_ratios=(0.7, 0.2, 0.1), zones = 4):
    all_image_paths, all_labels = [], []
    for folder_name in sorted(os.listdir(base_dir)):
        folder_path = os.path.join(base_dir, folder_name)
        if os.path.isdir(folder_path):
            for filename in sorted(os.listdir(folder_path)):
                if filename.endswith(".rgb.png"):
                    file_path = os.path.join(folder_path, filename)
                    all_image_paths.append(file_path)
                    all_labels.append(parse_image_filename(filename, zones))

    # Shuffle the dataset
    indices = np.random.permutation(len(all_image_paths))
    all_image_paths = np.array(all_image_paths)[indices]
    all_labels = np.array(all_labels)[indices]

    # Split the dataset
    train_size = int(len(all_image_paths) * split_ratios[0])
    val_size = int(len(all_image_paths) * split_ratios[1])

    train_paths = all_image_paths[:train_size]
    val_paths = all_image_paths[train_size:train_size + val_size]
    test_paths = all_image_paths[train_size + val_size:]

    train_labels = all_labels[:train_size]
    val_labels = all_labels[train_size:train_size + val_size]
    test_labels = all_labels[train_size + val_size:]

    # Create datasets
    train_ds = create_dataset(train_paths, train_labels, preprocess_func)
    val_ds = create_dataset(val_paths, val_labels, preprocess_func)
    test_ds = create_dataset(test_paths, test_labels, preprocess_func)

    return train_ds, val_ds, test_ds


def create_resnet_model(input_shape=(200, 200, 3), num_classes=4):
    """
    Create a model with a ResNet50 base, modified to suit the number of classes.
    
    Args:
    input_shape (tuple): Shape of the input images.
    num_classes (int): Number of classes for the output layer.
    
    Returns:
    tensorflow.keras.models.Model: The constructed model.
    """
    # Load ResNet50 as the base model, without the top layer (fully-connected layers).
    base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=Input(shape=input_shape))
    
    # Add a global average pooling layer to reduce feature map dimensions
    x = GlobalAveragePooling2D()(base_model.output)
    
    # Add a fully-connected layer with 1024 units and ReLU activation
    x = Dense(1024, activation='relu')(x)
    
    # Add the output layer with 'num_classes' units and softmax activation for classification
    outputs = Dense(num_classes, activation='softmax')(x)
    
    # Construct the final model
    model = Model(inputs=base_model.input, outputs=outputs)
    
    # Set all layers in the base model to be trainable
    for layer in base_model.layers:
        layer.trainable = True
    
    return model

def compile_and_train_model(model, train_ds, val_ds, epochs=1, zones = 4):
    # Configure the checkpoint to save the best model
    checkpoint = ModelCheckpoint(
        f'best_model_zones_{zones}.h5',  # Path where the model will be saved
        monitor='val_loss',  # Metric to monitor
        save_best_only=True,  # Save only the best model
        verbose=1  # Verbosity level
    )
    
    # Optional: Add early stopping to halt training when validation metric stops improving
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,  # Number of epochs with no improvement after which training will be stopped
        verbose=1
    )

    # Optional: Add TensorBoard to visualize training dynamics
    tensorboard = TensorBoard(log_dir=f'./azimuth_resnet_{zones}_logs')

    # Compile the model
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    # Train the model
    history = model.fit(
        train_ds,
        epochs=epochs,
        validation_data=val_ds,
        callbacks=[checkpoint, early_stopping, tensorboard]  # Include the checkpoint in the callbacks
    )
    
    return history


base_dir = '../data/raw_experimental_data'

evaluation_results = {
    'zones': [],
    'loss': [],
    'accuracy': []
}

zone_divisions = [4, 6, 12, 18, 36, 72, 120, 180, 360]
for zone in zone_divisions:
    train_ds, val_ds, test_ds = load_images_from_directory(
        base_dir, 
        lambda path: preprocess_image(path, (200, 200)), 
        split_ratios=(0.7, 0.2, 0.1),
        zones = zone,
    )

    model = create_resnet_model(num_classes=zone)
    history = compile_and_train_model(model, train_ds.batch(32), val_ds.batch(32), epochs=10, zones = zone)
    best_model = load_model(f'best_model_zones_{zone}.h5')

    results = best_model.evaluate(test_ds.batch(32), verbose=1)
    evaluation_results['zones'].append(zone)
    evaluation_results['loss'].append(results[0])
    evaluation_results['accuracy'].append(results[1])
# Out:
# Epoch 1/10
# 2993/2993 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9637
# Epoch 1: val_loss improved from inf to 0.07183, saving model to best_model_zones_4.h5
# /home/andrey/anaconda3/envs/A311/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2993/2993 [==============================] - 253s 78ms/step - loss: 0.1084 - accuracy: 0.9637 - val_loss: 0.0718 - val_accuracy: 0.9738
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9838
# Epoch 2: val_loss improved from 0.07183 to 0.05924, saving model to best_model_zones_4.h5
# 2993/2993 [==============================] - 231s 77ms/step - loss: 0.0467 - accuracy: 0.9838 - val_loss: 0.0592 - val_accuracy: 0.9795
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9868
# Epoch 3: val_loss improved from 0.05924 to 0.03356, saving model to best_model_zones_4.h5
# 2993/2993 [==============================] - 231s 77ms/step - loss: 0.0392 - accuracy: 0.9868 - val_loss: 0.0336 - val_accuracy: 0.9866
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0241 - accuracy: 0.9917
# Epoch 4: val_loss did not improve from 0.03356
# 2993/2993 [==============================] - 230s 77ms/step - loss: 0.0241 - accuracy: 0.9917 - val_loss: 0.0557 - val_accuracy: 0.9811
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9923
# Epoch 5: val_loss improved from 0.03356 to 0.02158, saving model to best_model_zones_4.h5
# 2993/2993 [==============================] - 221s 74ms/step - loss: 0.0234 - accuracy: 0.9923 - val_loss: 0.0216 - val_accuracy: 0.9923
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9944
# Epoch 6: val_loss did not improve from 0.02158
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 0.0218 - val_accuracy: 0.9927
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 0.9950
# Epoch 7: val_loss improved from 0.02158 to 0.01348, saving model to best_model_zones_4.h5
# 2993/2993 [==============================] - 223s 75ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0135 - val_accuracy: 0.9959
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9962
# Epoch 8: val_loss did not improve from 0.01348
# 2993/2993 [==============================] - 221s 74ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.0143 - val_accuracy: 0.9956
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9962
# Epoch 9: val_loss did not improve from 0.01348
# 2993/2993 [==============================] - 221s 74ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0172 - val_accuracy: 0.9947
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9973
# Epoch 10: val_loss did not improve from 0.01348
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.0088 - accuracy: 0.9973 - val_loss: 0.0260 - val_accuracy: 0.9904
# 428/428 [==============================] - 10s 22ms/step - loss: 0.0165 - accuracy: 0.9952
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1613 - accuracy: 0.9445
# Epoch 1: val_loss improved from inf to 0.09134, saving model to best_model_zones_6.h5
# 2993/2993 [==============================] - 241s 75ms/step - loss: 0.1613 - accuracy: 0.9445 - val_loss: 0.0913 - val_accuracy: 0.9680
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9781
# Epoch 2: val_loss improved from 0.09134 to 0.06748, saving model to best_model_zones_6.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0642 - accuracy: 0.9781 - val_loss: 0.0675 - val_accuracy: 0.9784
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9850
# Epoch 3: val_loss improved from 0.06748 to 0.05885, saving model to best_model_zones_6.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0435 - accuracy: 0.9850 - val_loss: 0.0589 - val_accuracy: 0.9799
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9885
# Epoch 4: val_loss improved from 0.05885 to 0.05710, saving model to best_model_zones_6.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0339 - accuracy: 0.9885 - val_loss: 0.0571 - val_accuracy: 0.9800
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0270 - accuracy: 0.9912
# Epoch 5: val_loss did not improve from 0.05710
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.0270 - accuracy: 0.9912 - val_loss: 0.0668 - val_accuracy: 0.9782
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9929
# Epoch 6: val_loss improved from 0.05710 to 0.02057, saving model to best_model_zones_6.h5
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.0206 - val_accuracy: 0.9928
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9937
# Epoch 7: val_loss did not improve from 0.02057
# 2993/2993 [==============================] - 217s 73ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.0207 - val_accuracy: 0.9933
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9949
# Epoch 8: val_loss did not improve from 0.02057
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.0240 - val_accuracy: 0.9921
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9956
# Epoch 9: val_loss did not improve from 0.02057
# 2993/2993 [==============================] - 217s 73ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.0370 - val_accuracy: 0.9888
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9953
# Epoch 10: val_loss did not improve from 0.02057
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.0197 - accuracy: 0.9953 - val_loss: 0.0212 - val_accuracy: 0.9937
# 428/428 [==============================] - 10s 23ms/step - loss: 0.0275 - accuracy: 0.9907
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.2500 - accuracy: 0.9123
# Epoch 1: val_loss improved from inf to 0.19094, saving model to best_model_zones_12.h5
# 2993/2993 [==============================] - 234s 73ms/step - loss: 0.2500 - accuracy: 0.9123 - val_loss: 0.1909 - val_accuracy: 0.9361
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9608
# Epoch 2: val_loss improved from 0.19094 to 0.06698, saving model to best_model_zones_12.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.1078 - accuracy: 0.9608 - val_loss: 0.0670 - val_accuracy: 0.9751
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0748 - accuracy: 0.9734
# Epoch 3: val_loss did not improve from 0.06698
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0748 - accuracy: 0.9734 - val_loss: 0.1756 - val_accuracy: 0.9480
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9812
# Epoch 4: val_loss did not improve from 0.06698
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0544 - accuracy: 0.9812 - val_loss: 0.1231 - val_accuracy: 0.9672
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9854
# Epoch 5: val_loss did not improve from 0.06698
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0419 - accuracy: 0.9854 - val_loss: 0.0964 - val_accuracy: 0.9710
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9894
# Epoch 6: val_loss improved from 0.06698 to 0.05425, saving model to best_model_zones_12.h5
# 2993/2993 [==============================] - 222s 74ms/step - loss: 0.0325 - accuracy: 0.9894 - val_loss: 0.0543 - val_accuracy: 0.9824
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9906
# Epoch 7: val_loss did not improve from 0.05425
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.0277 - accuracy: 0.9906 - val_loss: 0.1181 - val_accuracy: 0.9644
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9921
# Epoch 8: val_loss improved from 0.05425 to 0.04351, saving model to best_model_zones_12.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0232 - accuracy: 0.9921 - val_loss: 0.0435 - val_accuracy: 0.9865
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9936
# Epoch 9: val_loss did not improve from 0.04351
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0208 - accuracy: 0.9936 - val_loss: 0.0477 - val_accuracy: 0.9842
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9943
# Epoch 10: val_loss improved from 0.04351 to 0.03458, saving model to best_model_zones_12.h5
# 2993/2993 [==============================] - 220s 74ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0346 - val_accuracy: 0.9887
# 428/428 [==============================] - 10s 23ms/step - loss: 0.0387 - accuracy: 0.9877
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.3293 - accuracy: 0.8788
# Epoch 1: val_loss improved from inf to 0.35911, saving model to best_model_zones_18.h5
# 2993/2993 [==============================] - 235s 73ms/step - loss: 0.3293 - accuracy: 0.8788 - val_loss: 0.3591 - val_accuracy: 0.8739
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1450 - accuracy: 0.9457
# Epoch 2: val_loss improved from 0.35911 to 0.20289, saving model to best_model_zones_18.h5
# 2993/2993 [==============================] - 220s 74ms/step - loss: 0.1450 - accuracy: 0.9457 - val_loss: 0.2029 - val_accuracy: 0.9341
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0946 - accuracy: 0.9656
# Epoch 3: val_loss improved from 0.20289 to 0.11666, saving model to best_model_zones_18.h5
# 2993/2993 [==============================] - 221s 74ms/step - loss: 0.0946 - accuracy: 0.9656 - val_loss: 0.1167 - val_accuracy: 0.9606
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0657 - accuracy: 0.9768
# Epoch 4: val_loss did not improve from 0.11666
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0657 - accuracy: 0.9768 - val_loss: 0.1309 - val_accuracy: 0.9569
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0487 - accuracy: 0.9829
# Epoch 5: val_loss did not improve from 0.11666
# 2993/2993 [==============================] - 221s 74ms/step - loss: 0.0487 - accuracy: 0.9829 - val_loss: 0.1213 - val_accuracy: 0.9614
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9870
# Epoch 6: val_loss improved from 0.11666 to 0.10728, saving model to best_model_zones_18.h5
# 2993/2993 [==============================] - 220s 74ms/step - loss: 0.0389 - accuracy: 0.9870 - val_loss: 0.1073 - val_accuracy: 0.9673
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9891
# Epoch 7: val_loss improved from 0.10728 to 0.04990, saving model to best_model_zones_18.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.0323 - accuracy: 0.9891 - val_loss: 0.0499 - val_accuracy: 0.9833
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9908
# Epoch 8: val_loss did not improve from 0.04990
# 2993/2993 [==============================] - 221s 74ms/step - loss: 0.0281 - accuracy: 0.9908 - val_loss: 0.0745 - val_accuracy: 0.9775
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9915
# Epoch 9: val_loss did not improve from 0.04990
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0263 - accuracy: 0.9915 - val_loss: 0.0634 - val_accuracy: 0.9792
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9934
# Epoch 10: val_loss did not improve from 0.04990
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.0208 - accuracy: 0.9934 - val_loss: 0.0637 - val_accuracy: 0.9814
# 428/428 [==============================] - 10s 21ms/step - loss: 0.0453 - accuracy: 0.9836
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.5760 - accuracy: 0.7756
# Epoch 1: val_loss improved from inf to 1.26090, saving model to best_model_zones_36.h5
# 2993/2993 [==============================] - 234s 73ms/step - loss: 0.5760 - accuracy: 0.7756 - val_loss: 1.2609 - val_accuracy: 0.7015
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.2529 - accuracy: 0.9031
# Epoch 2: val_loss improved from 1.26090 to 0.30986, saving model to best_model_zones_36.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.2529 - accuracy: 0.9031 - val_loss: 0.3099 - val_accuracy: 0.8840
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1543 - accuracy: 0.9428
# Epoch 3: val_loss improved from 0.30986 to 0.19655, saving model to best_model_zones_36.h5
# 2993/2993 [==============================] - 220s 74ms/step - loss: 0.1542 - accuracy: 0.9429 - val_loss: 0.1965 - val_accuracy: 0.9300
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9631
# Epoch 4: val_loss did not improve from 0.19655
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.1035 - accuracy: 0.9631 - val_loss: 0.2386 - val_accuracy: 0.9240
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9729
# Epoch 5: val_loss did not improve from 0.19655
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0769 - accuracy: 0.9730 - val_loss: 0.2024 - val_accuracy: 0.9336
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9783
# Epoch 6: val_loss improved from 0.19655 to 0.16694, saving model to best_model_zones_36.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.0621 - accuracy: 0.9783 - val_loss: 0.1669 - val_accuracy: 0.9465
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0525 - accuracy: 0.9817
# Epoch 7: val_loss improved from 0.16694 to 0.12379, saving model to best_model_zones_36.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.0525 - accuracy: 0.9817 - val_loss: 0.1238 - val_accuracy: 0.9609
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9851
# Epoch 8: val_loss did not improve from 0.12379
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0428 - accuracy: 0.9851 - val_loss: 0.1421 - val_accuracy: 0.9578
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9872
# Epoch 9: val_loss did not improve from 0.12379
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0390 - accuracy: 0.9872 - val_loss: 0.1412 - val_accuracy: 0.9583
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9878
# Epoch 10: val_loss improved from 0.12379 to 0.12337, saving model to best_model_zones_36.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0368 - accuracy: 0.9878 - val_loss: 0.1234 - val_accuracy: 0.9626
# 428/428 [==============================] - 9s 21ms/step - loss: 0.1185 - accuracy: 0.9646
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.9754 - accuracy: 0.6087
# Epoch 1: val_loss improved from inf to 0.55410, saving model to best_model_zones_72.h5
# 2993/2993 [==============================] - 240s 75ms/step - loss: 0.9752 - accuracy: 0.6087 - val_loss: 0.5541 - val_accuracy: 0.7732
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.4461 - accuracy: 0.8191
# Epoch 2: val_loss improved from 0.55410 to 0.41059, saving model to best_model_zones_72.h5
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.4461 - accuracy: 0.8191 - val_loss: 0.4106 - val_accuracy: 0.8360
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.2681 - accuracy: 0.8961
# Epoch 3: val_loss improved from 0.41059 to 0.32700, saving model to best_model_zones_72.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.2681 - accuracy: 0.8961 - val_loss: 0.3270 - val_accuracy: 0.8818
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1761 - accuracy: 0.9338
# Epoch 4: val_loss improved from 0.32700 to 0.30357, saving model to best_model_zones_72.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.1761 - accuracy: 0.9338 - val_loss: 0.3036 - val_accuracy: 0.8946
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1279 - accuracy: 0.9538
# Epoch 5: val_loss improved from 0.30357 to 0.21370, saving model to best_model_zones_72.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.1279 - accuracy: 0.9538 - val_loss: 0.2137 - val_accuracy: 0.9306
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9649
# Epoch 6: val_loss did not improve from 0.21370
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.1002 - accuracy: 0.9649 - val_loss: 0.3144 - val_accuracy: 0.9003
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0830 - accuracy: 0.9702
# Epoch 7: val_loss did not improve from 0.21370
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.0830 - accuracy: 0.9702 - val_loss: 0.3355 - val_accuracy: 0.8969
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9760
# Epoch 8: val_loss improved from 0.21370 to 0.21082, saving model to best_model_zones_72.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0682 - accuracy: 0.9760 - val_loss: 0.2108 - val_accuracy: 0.9348
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9786
# Epoch 9: val_loss improved from 0.21082 to 0.14092, saving model to best_model_zones_72.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0621 - accuracy: 0.9786 - val_loss: 0.1409 - val_accuracy: 0.9557
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0525 - accuracy: 0.9823
# Epoch 10: val_loss did not improve from 0.14092
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0525 - accuracy: 0.9824 - val_loss: 0.2111 - val_accuracy: 0.9399
# 428/428 [==============================] - 9s 21ms/step - loss: 0.1393 - accuracy: 0.9577
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 1.6322 - accuracy: 0.4076
# Epoch 1: val_loss improved from inf to 1.17079, saving model to best_model_zones_120.h5
# 2993/2993 [==============================] - 242s 76ms/step - loss: 1.6321 - accuracy: 0.4076 - val_loss: 1.1708 - val_accuracy: 0.5171
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.6942 - accuracy: 0.7099
# Epoch 2: val_loss improved from 1.17079 to 0.53930, saving model to best_model_zones_120.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.6942 - accuracy: 0.7099 - val_loss: 0.5393 - val_accuracy: 0.7901
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.3671 - accuracy: 0.8596
# Epoch 3: val_loss improved from 0.53930 to 0.36317, saving model to best_model_zones_120.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.3671 - accuracy: 0.8597 - val_loss: 0.3632 - val_accuracy: 0.8647
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.2164 - accuracy: 0.9204
# Epoch 4: val_loss did not improve from 0.36317
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.2164 - accuracy: 0.9204 - val_loss: 0.4150 - val_accuracy: 0.8573
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1528 - accuracy: 0.9457
# Epoch 5: val_loss improved from 0.36317 to 0.32641, saving model to best_model_zones_120.h5
# 2993/2993 [==============================] - 222s 74ms/step - loss: 0.1528 - accuracy: 0.9457 - val_loss: 0.3264 - val_accuracy: 0.8940
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1137 - accuracy: 0.9608
# Epoch 6: val_loss did not improve from 0.32641
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.1137 - accuracy: 0.9608 - val_loss: 0.3689 - val_accuracy: 0.8845
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0950 - accuracy: 0.9676
# Epoch 7: val_loss improved from 0.32641 to 0.31195, saving model to best_model_zones_120.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.0950 - accuracy: 0.9676 - val_loss: 0.3120 - val_accuracy: 0.9050
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0774 - accuracy: 0.9735
# Epoch 8: val_loss did not improve from 0.31195
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.0774 - accuracy: 0.9734 - val_loss: 0.4561 - val_accuracy: 0.8681
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9770
# Epoch 9: val_loss did not improve from 0.31195
# 2993/2993 [==============================] - 220s 74ms/step - loss: 0.0680 - accuracy: 0.9770 - val_loss: 0.3679 - val_accuracy: 0.8944
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0600 - accuracy: 0.9798
# Epoch 10: val_loss improved from 0.31195 to 0.27993, saving model to best_model_zones_120.h5
# 2993/2993 [==============================] - 222s 74ms/step - loss: 0.0600 - accuracy: 0.9798 - val_loss: 0.2799 - val_accuracy: 0.9235
# 428/428 [==============================] - 9s 21ms/step - loss: 0.2665 - accuracy: 0.9270
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 2.0251 - accuracy: 0.2902
# Epoch 1: val_loss improved from inf to 1.50553, saving model to best_model_zones_180.h5
# 2993/2993 [==============================] - 233s 73ms/step - loss: 2.0251 - accuracy: 0.2902 - val_loss: 1.5055 - val_accuracy: 0.3935
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 1.0249 - accuracy: 0.5708
# Epoch 2: val_loss improved from 1.50553 to 0.96457, saving model to best_model_zones_180.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 1.0249 - accuracy: 0.5708 - val_loss: 0.9646 - val_accuracy: 0.6248
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.5954 - accuracy: 0.7664
# Epoch 3: val_loss improved from 0.96457 to 0.69028, saving model to best_model_zones_180.h5
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.5954 - accuracy: 0.7664 - val_loss: 0.6903 - val_accuracy: 0.7499
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.3409 - accuracy: 0.8754
# Epoch 4: val_loss improved from 0.69028 to 0.50492, saving model to best_model_zones_180.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.3409 - accuracy: 0.8754 - val_loss: 0.5049 - val_accuracy: 0.8340
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.2210 - accuracy: 0.9228
# Epoch 5: val_loss improved from 0.50492 to 0.41024, saving model to best_model_zones_180.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.2210 - accuracy: 0.9228 - val_loss: 0.4102 - val_accuracy: 0.8715
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1622 - accuracy: 0.9447
# Epoch 6: val_loss improved from 0.41024 to 0.38194, saving model to best_model_zones_180.h5
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.1622 - accuracy: 0.9447 - val_loss: 0.3819 - val_accuracy: 0.8834
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1319 - accuracy: 0.9553
# Epoch 7: val_loss did not improve from 0.38194
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.1319 - accuracy: 0.9553 - val_loss: 0.4616 - val_accuracy: 0.8693
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1028 - accuracy: 0.9649
# Epoch 8: val_loss did not improve from 0.38194
# 2993/2993 [==============================] - 220s 74ms/step - loss: 0.1029 - accuracy: 0.9649 - val_loss: 0.3890 - val_accuracy: 0.8917
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0915 - accuracy: 0.9684
# Epoch 9: val_loss did not improve from 0.38194
# 2993/2993 [==============================] - 218s 73ms/step - loss: 0.0916 - accuracy: 0.9684 - val_loss: 0.3831 - val_accuracy: 0.9012
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0775 - accuracy: 0.9740
# Epoch 10: val_loss improved from 0.38194 to 0.27716, saving model to best_model_zones_180.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0775 - accuracy: 0.9740 - val_loss: 0.2772 - val_accuracy: 0.9279
# 428/428 [==============================] - 9s 21ms/step - loss: 0.2799 - accuracy: 0.9288
# Epoch 1/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 2.9450 - accuracy: 0.1492
# Epoch 1: val_loss improved from inf to 2.90762, saving model to best_model_zones_360.h5
# 2993/2993 [==============================] - 234s 73ms/step - loss: 2.9447 - accuracy: 0.1492 - val_loss: 2.9076 - val_accuracy: 0.1940
# Epoch 2/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 1.5768 - accuracy: 0.4231
# Epoch 2: val_loss improved from 2.90762 to 1.22886, saving model to best_model_zones_360.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 1.5766 - accuracy: 0.4232 - val_loss: 1.2289 - val_accuracy: 0.5542
# Epoch 3/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.7788 - accuracy: 0.7328
# Epoch 3: val_loss improved from 1.22886 to 0.72386, saving model to best_model_zones_360.h5
# 2993/2993 [==============================] - 220s 73ms/step - loss: 0.7787 - accuracy: 0.7329 - val_loss: 0.7239 - val_accuracy: 0.7671
# Epoch 4/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.3809 - accuracy: 0.8761
# Epoch 4: val_loss improved from 0.72386 to 0.59871, saving model to best_model_zones_360.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.3808 - accuracy: 0.8761 - val_loss: 0.5987 - val_accuracy: 0.8252
# Epoch 5/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.2480 - accuracy: 0.9205
# Epoch 5: val_loss did not improve from 0.59871
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.2480 - accuracy: 0.9205 - val_loss: 0.8445 - val_accuracy: 0.7663
# Epoch 6/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1783 - accuracy: 0.9419
# Epoch 6: val_loss did not improve from 0.59871
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.1783 - accuracy: 0.9419 - val_loss: 0.7006 - val_accuracy: 0.8206
# Epoch 7/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1434 - accuracy: 0.9533
# Epoch 7: val_loss improved from 0.59871 to 0.54602, saving model to best_model_zones_360.h5
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.1434 - accuracy: 0.9533 - val_loss: 0.5460 - val_accuracy: 0.8648
# Epoch 8/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9624
# Epoch 8: val_loss improved from 0.54602 to 0.48268, saving model to best_model_zones_360.h5
# 2993/2993 [==============================] - 221s 74ms/step - loss: 0.1156 - accuracy: 0.9624 - val_loss: 0.4827 - val_accuracy: 0.8901
# Epoch 9/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9672
# Epoch 9: val_loss did not improve from 0.48268
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0999 - accuracy: 0.9672 - val_loss: 0.8632 - val_accuracy: 0.8017
# Epoch 10/10
# 2992/2993 [============================>.] - ETA: 0s - loss: 0.0859 - accuracy: 0.9719
# Epoch 10: val_loss did not improve from 0.48268
# 2993/2993 [==============================] - 219s 73ms/step - loss: 0.0858 - accuracy: 0.9719 - val_loss: 0.5524 - val_accuracy: 0.8726
# 428/428 [==============================] - 10s 23ms/step - loss: 0.4794 - accuracy: 0.8901

# %%
evaluation_results
# Out:
# {'zones': [4, 6, 12, 18, 36, 72, 120, 180, 360],
#  'loss': [0.01649949699640274,
#   0.027539193630218506,
#   0.03867405652999878,
#   0.04533742740750313,
#   0.11847370117902756,
#   0.1393391340970993,
#   0.26651108264923096,
#   0.27987173199653625,
#   0.47942522168159485],
#  'accuracy': [0.9951754212379456,
#   0.9907163977622986,
#   0.9877192974090576,
#   0.9836257100105286,
#   0.9646198749542236,
#   0.9576754570007324,
#   0.9269737005233765,
#   0.9288011789321899,
#   0.8901315927505493]}

# %%
evaluation_results = {
    'zones': [],
    'loss': [],
    'accuracy': []
}

zone_divisions = [4, 6, 12, 18, 36, 72, 120, 180, 360]
for zone in zone_divisions:
    
    train_ds, val_ds, test_ds = load_images_from_directory(
        base_dir, 
        lambda path: preprocess_image(path, (200, 200)), 
        split_ratios=(0.7, 0.2, 0.1),
        zones = zone,
    )
    
    
    
    best_model = load_model(f'az_models_densenet/best_model_zones_{zone}.h5')

    results = best_model.evaluate(test_ds.batch(32), verbose=1)
    evaluation_results['zones'].append(zone)
    evaluation_results['loss'].append(results[0])
    evaluation_results['accuracy'].append(results[1])
# Out:
# 428/428 [==============================] - 10s 21ms/step - loss: 0.0053 - accuracy: 0.9980
# 428/428 [==============================] - 11s 24ms/step - loss: 0.0093 - accuracy: 0.9971
# 428/428 [==============================] - 10s 22ms/step - loss: 0.0280 - accuracy: 0.9914
# 428/428 [==============================] - 10s 22ms/step - loss: 0.0203 - accuracy: 0.9932
# 428/428 [==============================] - 11s 24ms/step - loss: 0.0571 - accuracy: 0.9804
# 428/428 [==============================] - 10s 21ms/step - loss: 0.1552 - accuracy: 0.9502
# 428/428 [==============================] - 10s 21ms/step - loss: 0.2308 - accuracy: 0.9159
# 428/428 [==============================] - 10s 21ms/step - loss: 0.2801 - accuracy: 0.9105
# 428/428 [==============================] - 10s 21ms/step - loss: 0.2831 - accuracy: 0.9209

# %%
real_image_paths = ["/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3703.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3704.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3705.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3706.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4090.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4091.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4092.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4096.png", 
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4097.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4098.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4099.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4100.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4101.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4102.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4103.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4104.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4105.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4106.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4107.png"]
real_elevation_labels = [0, 0, 45, 45, 0, 0, 0, 75, 75, 75, 0, 0, 75, 0, 0, 0, 0, 0, 0]  # Dummy elevation values
real_azimuth_labels = [105, 250, 275, 305, 100, 3, 280, 90, 40, 135, 175, 268, 267, 95, 45, 285, 330, 1, 90]  # Dummy azimuth values

def preprocess_real_images(image_path):
    # This assumes the preprocess function and grayscale conversion are correctly defined
    rgb_image = tf.io.read_file(image_path)
    rgb_image = tf.image.decode_png(rgb_image, channels=3)  # Adjust if images are not PNG
    rgb_image = tf.image.resize(rgb_image, [200, 200])
    rgb_image = rgb_image / 255.0  # Normalize to [0,1]
    return rgb_image  # Assuming this function is defined

def preprocess_image(image_path):
    """Load and preprocess an image."""
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)  # Assuming images are in PNG format
    image = tf.image.resize(image, [200, 200])  # Resize to the desired size for your model
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image  # Here, keep it in RGB if that's what the model expects

def create_tf_dataset(image_paths, elevation_labels, azimuth_labels):
    """Create a TensorFlow dataset from image paths and labels."""
    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices({
        'elevation': tf.cast(elevation_labels, tf.int64),
        'azimuth': tf.cast(azimuth_labels, tf.int64)  // (360)
    })

    # Combine into a single dataset
    dataset = tf.data.Dataset.zip((image_ds, labels_ds))
    return dataset

real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)
real_dataset = real_dataset.batch(32)  # Batch the dataset for model evaluation or visualization

# %%
import matplotlib.pyplot as plt

def predict_and_visualize(model, dataset, sample_size=22):
    """
    Predicts using the model on the dataset and visualizes the results in a vertical layout.
    
    Args:
    model (tf.keras.Model): The trained model.
    dataset (tf.data.Dataset): The dataset for prediction.
    sample_size (int): Number of predictions to visualize.
    """
    # Take samples for prediction
    sample_dataset = dataset.take(sample_size)
    
    # Since the dataset is batched, predictions and visualization must handle batches
    for images, labels in sample_dataset:  # Iterate over batches
        predictions = model.predict(images)  # Predict a whole batch

        plt.figure(figsize=(3, 3.5 * sample_size))  # Adjust the figure size for vertical layout
        plt.suptitle('Predictions', fontsize=12)

        for i, image in enumerate(images):  # Now iterate over images in the batch
            plt.subplot(sample_size, 1, i + 1)  # Change subplot to arrange images vertically
            predicted_label = np.argmax(predictions[i])
            plt.imshow(image.numpy().squeeze(), cmap='gray')  # Adjust color mapping if necessary
            plt.title(f"Predicted Label: {predicted_label}", fontsize=10)  # Adjust font size
            plt.axis('off')

        plt.subplots_adjust(hspace=.4)  # Adjust the horizontal spacing between subplots
        plt.show()

# Example of how to call the function
predict_and_visualize(best_model, real_dataset)
# Out:
# 1/1 [==============================] - 0s 17ms/step

# %%
real_image_paths = ["/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3703.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3704.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3705.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_3706.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4090.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4091.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4092.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4096.png", 
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4097.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4098.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4099.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4100.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4101.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4102.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4103.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4104.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4105.png",
                    "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4106.png", "/home/andrey/msds_practicum/msds_practicum/data/real_data/image_4107.png"]
real_elevation_labels = [0, 0, 45, 45, 0, 0, 0, 75, 75, 75, 0, 0, 75, 0, 0, 0, 0, 0, 0]  # Dummy elevation values
real_azimuth_labels = [105, 250, 275, 305, 100, 3, 280, 90, 40, 135, 175, 268, 267, 95, 45, 285, 330, 1, 90]  # Dummy azimuth values
import tensorflow as tf
import numpy as np
import tensorflow as tf
import numpy as np

import tensorflow as tf
import numpy as np

def preprocess_real_images(image_path):
    # This assumes the preprocess function and grayscale conversion are correctly defined
    rgb_image = tf.io.read_file(image_path)
    rgb_image = tf.image.decode_png(rgb_image, channels=3)  # Adjust if images are not PNG
    rgb_image = tf.image.resize(rgb_image, [200, 200])
    rgb_image = rgb_image / 255.0  # Normalize to [0,1]
    return rgb_to_three_channel_grayscale(rgb_image)  # Assuming this function is defined

def rgb_to_three_channel_grayscale(image):
    """Convert an RGB image to 3-channel grayscale."""
    grayscale = tf.image.rgb_to_grayscale(image)
    grayscale = tf.tile(grayscale, [1, 1, 3])  # Repeat the grayscale channel three times
    return grayscale

def preprocess_image(image_path):
    """Load and preprocess an image."""
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)  # Assuming images are in PNG format
    image = tf.image.resize(image, [200, 200])  # Resize to the desired size for your model
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image  # Here, keep it in RGB if that's what the model expects

def create_tf_dataset(image_paths, elevation_labels, azimuth_labels):
    """Create a TensorFlow dataset from image paths and labels."""
    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices({
        'elevation': tf.cast(elevation_labels, tf.int64),
        'azimuth': tf.cast(azimuth_labels, tf.int64)  // (360/zones)
    })

    # Combine into a single dataset
    dataset = tf.data.Dataset.zip((image_ds, labels_ds))
    return dataset

real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)
real_dataset = real_dataset.batch(32)  # Batch the dataset for model evaluation or visualization
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 55
#      52     dataset = tf.data.Dataset.zip((image_ds, labels_ds))
#      53     return dataset
# ---> 55 real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)
#      56 real_dataset = real_dataset.batch(32)  # Batch the dataset for model evaluation or visualization
#
# Cell In[5], line 48, in create_tf_dataset(image_paths, elevation_labels, azimuth_labels)
#      44 """Create a TensorFlow dataset from image paths and labels."""
#      45 image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
#      46 labels_ds = tf.data.Dataset.from_tensor_slices({
#      47     'elevation': tf.cast(elevation_labels, tf.int64),
# ---> 48     'azimuth': tf.cast(azimuth_labels, tf.int64)  // (360/zones)
#      49 })
#      51 # Combine into a single dataset
#      52 dataset = tf.data.Dataset.zip((image_ds, labels_ds))
#
# NameError: name 'zones' is not defined

# %%
test_ds

# %%
real_dataset

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_samples_with_predictions(dataset, model, title, num_samples=3):
    plt.figure(figsize=(15, 5))
    plt.suptitle(title, fontsize=16)
    
    for images, labels in dataset.take(1):  # Take one batch from the dataset
        if images.shape[0] < num_samples:
            raise ValueError("Not enough samples in the batch. Increase batch size or reduce num_samples.")
        
        # Get model predictions
        predictions = model.predict(images)
        predicted_labels = np.argmax(predictions, axis=1)  # Assuming model outputs logits or softmax
        
        for i in range(num_samples):
            plt.subplot(1, num_samples, i + 1)
            plt.imshow(images[i].numpy())
            
            # Adjust how labels are accessed based on your dataset structure
            # Check if labels are a dictionary and adjust accordingly
            if isinstance(labels, dict):
                actual_label = f"Elevation: {labels['elevation'][i].numpy()}, Azimuth: {labels['azimuth'][i].numpy()}"
            else:
                actual_label = labels[i].numpy()
                
            predicted_label = predicted_labels[i]
            plt.title(f"True: {actual_label}\nPred: {predicted_label}")
            plt.axis('off')
    plt.show()

# Example usage, make sure the model and datasets are correctly configured
batch_size = 3
plot_samples_with_predictions(real_dataset.batch(batch_size), model, "Real Dataset")

# Ensure the model is correctly loaded and compiled
# Assuming `model` is your loaded and compiled model and the datasets are batched

plot_samples_with_predictions(train_ds.batch(batch_size), model, "Training Samples")
plot_samples_with_predictions(val_ds.batch(batch_size), model, "Validation Samples")
plot_samples_with_predictions(test_ds.batch(batch_size), model, "Test Samples")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 35
#      33 # Example usage, make sure the model and datasets are correctly configured
#      34 batch_size = 3
# ---> 35 plot_samples_with_predictions(real_dataset.batch(batch_size), model, "Real Dataset")
#      37 # Ensure the model is correctly loaded and compiled
#      38 # Assuming `model` is your loaded and compiled model and the datasets are batched
#      40 plot_samples_with_predictions(train_ds.batch(batch_size), model, "Training Samples")
#
# NameError: name 'real_dataset' is not defined

# %%
real_dataset = create_tf_dataset(real_image_paths, real_elevation_labels, real_azimuth_labels)

# Example of how to check dataset structure
for images, labels in real_dataset.take(1):
    print(f"Image shape: {images.shape}, Label: {labels}")
